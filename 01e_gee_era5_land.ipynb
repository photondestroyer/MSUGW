# %% [markdown]
# # 01e: ERA5-Land
#
# **Why:** Meteorological controls for expected-function matching.
#
# - Asset ID: `ECMWF/ERA5_LAND/HOURLY`
# - Outputs: server-side GeoTIFF tasks in Google Drive folder `raw/`; local logs and task registry under `DRIVE_ROOT`
# - Author: `<name / institution>`
# - This notebook runs locally, preserves native bands and QA values, and does not select away quality metadata.

# %%
# Local bootstrap. Installs are quiet so the notebook stays readable.
# %pip -q install earthengine-api xee xarray netCDF4 h5netcdf geopandas rioxarray regionmask "dask[diagnostics]" requests tqdm python-dotenv pyyaml matplotlib pandas pyproj shapely compliance-checker
from pathlib import Path
import os, sys, json, time, logging, traceback
from datetime import datetime

PROJECT_ID = os.getenv("GEE_PROJECT", "ee-ishansinhagzb")
import ee
ee.Authenticate()
ee.Initialize(project=PROJECT_ID)

# Local files hold configuration, logs, and task metadata. GeoTIFF outputs go to Google Drive via EE.
DRIVE_ROOT = Path(os.getenv("OGALLALA_PHASE0_ROOT", "./Ogallala_Phase0"))
SETUP_DIR = DRIVE_ROOT / '00_setup'
SETUP_DIR.mkdir(parents=True, exist_ok=True)
UTILS_SOURCE = '"""Shared utilities for the Ogallala Phase 0 Colab notebooks."""\nfrom __future__ import annotations\n\nimport json\nimport logging\nimport math\nimport os\nimport time\nimport traceback\nfrom datetime import datetime, timezone\nfrom functools import wraps\nfrom pathlib import Path\nfrom typing import Any, Callable, Iterable\n\nimport numpy as np\nimport pandas as pd\n\nREGISTRY_COLUMNS = [\n    "timestamp", "notebook_id", "dataset", "task_id_or_file", "pathway",\n    "status", "start_time", "end_time", "n_bytes", "error_message", "retries",\n]\nTERMINAL = {"COMPLETED", "FAILED"}\n\n\ndef utc_now() -> str:\n    """Return an ISO-8601 UTC timestamp."""\n    return datetime.now(timezone.utc).isoformat()\n\n\ndef ensure_layout(root: Path, leaf: str) -> Path:\n    """Create the standard Drive tree and return one dataset leaf."""\n    root = Path(root)\n    for path in [root / "00_setup", root / "logs", root / "manifests"]:\n        path.mkdir(parents=True, exist_ok=True)\n    for name in ["raw", "cf", "qc"]:\n        (root / leaf / name).mkdir(parents=True, exist_ok=True)\n    registry = root / "logs" / "task_registry.csv"\n    if not registry.exists():\n        pd.DataFrame(columns=REGISTRY_COLUMNS).to_csv(registry, index=False)\n    return root / leaf\n\n\ndef configure_logger(notebook_id: str, root: Path) -> tuple[logging.Logger, Path]:\n    """Configure rotating file and stdout logging for a notebook."""\n    from logging.handlers import RotatingFileHandler\n    log_dir = Path(root) / "logs"\n    log_dir.mkdir(parents=True, exist_ok=True)\n    path = log_dir / f"{notebook_id}_{datetime.now().strftime(\'%Y%m%dT%H%M%S\')}.log"\n    logger = logging.getLogger(notebook_id)\n    logger.setLevel(logging.INFO)\n    logger.handlers.clear()\n    formatter = logging.Formatter("%(asctime)s %(levelname)s %(message)s")\n    file_handler = RotatingFileHandler(path, maxBytes=50 * 1024 * 1024, backupCount=3)\n    file_handler.setFormatter(formatter)\n    stream_handler = logging.StreamHandler()\n    stream_handler.setFormatter(formatter)\n    logger.addHandler(file_handler)\n    logger.addHandler(stream_handler)\n    return logger, path\n\n\ndef registry_path(root: Path) -> Path:\n    """Return the shared task registry path."""\n    path = Path(root) / "logs" / "task_registry.csv"\n    path.parent.mkdir(parents=True, exist_ok=True)\n    if not path.exists():\n        pd.DataFrame(columns=REGISTRY_COLUMNS).to_csv(path, index=False)\n    return path\n\n\ndef append_registry(root: Path, **values: Any) -> None:\n    """Append a normalized task or file event to the registry."""\n    row = {column: values.get(column, "") for column in REGISTRY_COLUMNS}\n    row["timestamp"] = row["timestamp"] or utc_now()\n    path = registry_path(root)\n    frame = pd.DataFrame([row], columns=REGISTRY_COLUMNS)\n    frame.to_csv(path, mode="a", header=path.stat().st_size == 0, index=False)\n\n\ndef logged_step(notebook_id: str, dataset: str, root: Path, logger: logging.Logger) -> Callable:\n    """Decorate an I/O step so failures are logged and recorded."""\n    def decorator(function: Callable) -> Callable:\n        @wraps(function)\n        def wrapper(*args: Any, **kwargs: Any) -> Any:\n            start = utc_now()\n            try:\n                result = function(*args, **kwargs)\n                append_registry(root, notebook_id=notebook_id, dataset=dataset,\n                                task_id_or_file=function.__name__, pathway="xee",\n                                status="COMPLETED", start_time=start, end_time=utc_now())\n                return result\n            except Exception as exc:\n                logger.error("%s failed: %s\\n%s", function.__name__, exc, traceback.format_exc())\n                append_registry(root, notebook_id=notebook_id, dataset=dataset,\n                                task_id_or_file=function.__name__, pathway="xee",\n                                status="FAILED", start_time=start, end_time=utc_now(),\n                                error_message=str(exc))\n                return None\n        return wrapper\n    return decorator\n\n\nclass BatchManager:\n    """Submit non-blocking Earth Engine exports under a small concurrency cap."""\n\n    def __init__(self, root: Path, notebook_id: str, dataset: str,\n                 logger: logging.Logger, max_concurrent: int = 20,\n                 max_daily_tasks: int = 2500) -> None:\n        self.root = Path(root)\n        self.notebook_id = notebook_id\n        self.dataset = dataset\n        self.logger = logger\n        self.max_concurrent = max_concurrent\n        self.max_daily_tasks = max_daily_tasks\n\n    def active_count(self) -> int:\n        """Count locally registered active submissions."""\n        frame = pd.read_csv(registry_path(self.root))\n        if frame.empty:\n            return 0\n        return int(frame["status"].isin(["STARTED", "RUNNING"]).sum())\n\n    def wait_for_slot(self) -> None:\n        """Wait before submitting when the local active cap is reached."""\n        while self.active_count() >= self.max_concurrent:\n            self.logger.info("Active cap reached; sleeping 60 seconds")\n            time.sleep(60)\n\n    def start(self, task: Any, description: str, retries: int = 3) -> str:\n        """Start a task with retry backoff and return its Earth Engine ID."""\n        self.wait_for_slot()\n        delays = [10, 60, 300]\n        start_time = utc_now()\n        for attempt in range(retries + 1):\n            try:\n                task.start()\n                task_id = getattr(task, "id", "") or task.status().get("id", "")\n                append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                task_id_or_file=task_id, pathway="batch", status="STARTED",\n                                start_time=start_time, retries=attempt)\n                time.sleep(2)\n                return task_id\n            except Exception as exc:\n                message = str(exc).lower()\n                retryable = "429" in message or "rate limit" in message or "quota" in message\n                if not retryable or attempt >= retries:\n                    append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                    task_id_or_file=description, pathway="batch", status="FAILED",\n                                    start_time=start_time, end_time=utc_now(),\n                                    error_message=str(exc), retries=attempt)\n                    self.logger.error("Export failed: %s", exc)\n                    return ""\n                delay = delays[min(attempt, len(delays) - 1)]\n                self.logger.warning("Rate limit on %s; retrying in %ss", description, delay)\n                append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                task_id_or_file=description, pathway="batch", status="RETRIED",\n                                start_time=start_time, retries=attempt + 1,\n                                error_message=str(exc))\n                time.sleep(delay)\n        return ""\n\n    def submit_image(self, image: Any, description: str, folder: str,\n                     prefix: str, region: Any, scale: int, crs: str) -> str:\n        """Create and start a Drive GeoTIFF export without polling."""\n        import ee\n        task = ee.batch.Export.image.toDrive(\n            image=image, description=description, folder=folder,\n            fileNamePrefix=prefix, region=region, scale=scale, crs=crs,\n            maxPixels=1e13, fileFormat="GeoTIFF",\n        )\n        return self.start(task, description)\n\n    def monitor_once(self) -> pd.DataFrame:\n        """Poll registered Earth Engine tasks once and update their statuses."""\n        import ee\n        path = registry_path(self.root)\n        frame = pd.read_csv(path)\n        if frame.empty:\n            return frame\n        for index, row in frame.iterrows():\n            if row["status"] not in ["STARTED", "RUNNING"] or not row["task_id_or_file"]:\n                continue\n            try:\n                status = ee.data.getTaskStatus(str(row["task_id_or_file"]))[0]\n                state = status.get("state", "UNKNOWN")\n                mapped = {"READY": "RUNNING", "RUNNING": "RUNNING",\n                          "COMPLETED": "COMPLETED", "FAILED": "FAILED",\n                          "CANCELLED": "FAILED"}.get(state, state)\n                frame.loc[index, "status"] = mapped\n                frame.loc[index, "end_time"] = utc_now() if mapped in TERMINAL else ""\n                frame.loc[index, "error_message"] = status.get("error_message", "")\n            except Exception as exc:\n                self.logger.warning("Could not poll %s: %s", row["task_id_or_file"], exc)\n        frame.to_csv(path, index=False)\n        return frame\n\n\ndef normalize_projected_dataset(ds: Any, crs: str = "EPSG:5070") -> Any:\n    """Normalize raster dimensions and add projected CF coordinates."""\n    import xarray as xr\n    if "lat" in ds.dims and "y" not in ds.dims:\n        ds = ds.rename({"lat": "y"})\n    if "lon" in ds.dims and "x" not in ds.dims:\n        ds = ds.rename({"lon": "x"})\n    if "y" not in ds.coords:\n        ds = ds.assign_coords(y=np.arange(ds.sizes.get("y", 1), dtype=float))\n    if "x" not in ds.coords:\n        ds = ds.assign_coords(x=np.arange(ds.sizes.get("x", 1), dtype=float))\n    ds["y"].attrs.update({"standard_name": "projection_y_coordinate", "units": "m", "axis": "Y"})\n    ds["x"].attrs.update({"standard_name": "projection_x_coordinate", "units": "m", "axis": "X"})\n    if "lat" not in ds:\n        ds["lat"] = xr.DataArray(np.broadcast_to(ds["y"].values[:, None],\n                                                  (ds.sizes["y"], ds.sizes["x"])), dims=("y", "x"))\n    if "lon" not in ds:\n        ds["lon"] = xr.DataArray(np.broadcast_to(ds["x"].values[None, :],\n                                                  (ds.sizes["y"], ds.sizes["x"])), dims=("y", "x"))\n    ds["lat"].attrs.update({"standard_name": "latitude", "units": "degrees_north"})\n    ds["lon"].attrs.update({"standard_name": "longitude", "units": "degrees_east"})\n    return ds\n\n\ndef write_cf_netcdf(ds: Any, path: Path, attrs: dict[str, Any],\n                    variable_attrs: dict[str, dict[str, Any]] | None = None) -> Path:\n    """Write a compressed projected NetCDF with the Phase 0 CF contract."""\n    import xarray as xr\n    path = Path(path)\n    path.parent.mkdir(parents=True, exist_ok=True)\n    ds = normalize_projected_dataset(ds)\n    ds.attrs.update({\n        "Conventions": "CF-1.8", "title": attrs.get("title", "Ogallala Phase 0 dataset"),\n        "history": f"{utc_now()} notebook={attrs.get(\'notebook_id\', \'unknown\')} git_commit=placeholder",\n        "institution": attrs.get("institution", "Ogallala Phase 0 research team"),\n        "source": attrs.get("source", "Google Earth Engine"),\n        "gee_asset_id": attrs.get("gee_asset_id", ""),\n        "references": attrs.get("references", "Groundwater Buffering of Ecosystem Function During Drought Phase 0 plan"),\n        "comment": attrs.get("comment", "Master grid: EPSG:5070; native bands and QA bands preserved."),\n        "featureType": attrs.get("featureType", "grid"),\n    })\n    ds["crs"] = xr.DataArray(0, attrs={\n        "grid_mapping_name": "albers_conical_equal_area", "semi_major_axis": 6378137.0,\n        "inverse_flattening": 298.257222101, "false_easting": 0.0, "false_northing": 0.0,\n        "spatial_ref": crs_wkt(),\n    })\n    variable_attrs = variable_attrs or {}\n    for name, variable in ds.data_vars.items():\n        if name == "crs":\n            continue\n        defaults = {"long_name": name, "units": "1", "_FillValue": -9999.0,\n                    "grid_mapping": "crs", "coordinates": "lat lon"}\n        defaults.update(variable_attrs.get(name, {}))\n        variable.attrs.update(defaults)\n    encoding: dict[str, dict[str, Any]] = {}\n    for name, variable in ds.data_vars.items():\n        if name == "crs":\n            continue\n        fill = variable.attrs.get("_FillValue", -9999.0)\n        encoding[name] = {"zlib": True, "complevel": 4, "_FillValue": fill}\n        if "time" in variable.dims:\n            encoding[name]["chunksizes"] = tuple(min(24, ds.sizes[d]) for d in variable.dims)\n    if "time" in ds.coords:\n        ds["time"].attrs.update({"standard_name": "time", "long_name": "time",\n                                  "units": "days since 1970-01-01 00:00:00",\n                                  "calendar": "proleptic_gregorian", "axis": "T"})\n        encoding["time"] = {"units": "days since 1970-01-01 00:00:00",\n                             "calendar": "proleptic_gregorian"}\n    ds.to_netcdf(path, format="NETCDF4_CLASSIC", engine="netcdf4", encoding=encoding)\n    return path\n\n\ndef crs_wkt() -> str:\n    """Return a WKT representation for the master Albers grid."""\n    try:\n        from pyproj import CRS\n        return CRS.from_epsg(5070).to_wkt()\n    except Exception:\n        return "EPSG:5070"\n\n\ndef qc_netcdf(path: Path, qc_dir: Path) -> dict[str, Any]:\n    """Create summary statistics and a quicklook for a NetCDF file."""\n    import matplotlib.pyplot as plt\n    import xarray as xr\n    path, qc_dir = Path(path), Path(qc_dir)\n    qc_dir.mkdir(parents=True, exist_ok=True)\n    ds = xr.open_dataset(path)\n    summary: dict[str, Any] = {}\n    for name, value in ds.data_vars.items():\n        if name == "crs":\n            continue\n        array = value.values.astype(float)\n        finite = array[np.isfinite(array)]\n        summary[name] = {"min": float(np.min(finite)) if finite.size else None,\n                         "max": float(np.max(finite)) if finite.size else None,\n                         "mean": float(np.mean(finite)) if finite.size else None,\n                         "std": float(np.std(finite)) if finite.size else None,\n                         "n_valid": int(finite.size)}\n        if finite.size:\n            image = np.nanmean(array, axis=0) if "time" in value.dims else array\n            plt.imsave(qc_dir / f"{path.stem}_{name}.png", image, cmap="viridis")\n    summary_path = qc_dir / f"{path.stem}_summary_stats.json"\n    summary_path.write_text(json.dumps(summary, indent=2), encoding="utf-8")\n    ds.close()\n    return summary\n\n\ndef write_manifest(root: Path, notebook_id: str, files: Iterable[Path],\n                   dataset: str, status: str = "COMPLETED") -> Path:\n    """Write provenance metadata for files produced by one notebook."""\n    entries = []\n    for file_path in files:\n        file_path = Path(file_path)\n        if file_path.exists():\n            entries.append({"file": str(file_path), "size_bytes": file_path.stat().st_size,\n                            "cf_version": "CF-1.8", "dataset": dataset})\n    path = Path(root) / "manifests" / f"{notebook_id}_manifest.json"\n    path.parent.mkdir(parents=True, exist_ok=True)\n    path.write_text(json.dumps({"notebook_id": notebook_id, "status": status,\n                                "files": entries}, indent=2), encoding="utf-8")\n    return path\n'
(SETUP_DIR / 'utils.py').write_text(UTILS_SOURCE, encoding='utf-8')
sys.path.insert(0, str(SETUP_DIR))
from utils import *
NOTEBOOK_ID = '01e'
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

CONFIG_PATH = DRIVE_ROOT / '00_setup' / 'config.yaml'
if not CONFIG_PATH.exists():
    raise FileNotFoundError('Run 00_setup_aoi_and_config.ipynb first to create config.yaml and the AOI.')
CONFIG = yaml.safe_load(CONFIG_PATH.read_text(encoding='utf-8'))
DRY_RUN = bool(CONFIG.get('DRY_RUN', False))
AOI = ee.Geometry(json.loads((DRIVE_ROOT / '00_setup' / 'aoi_ee_geometry.json').read_text()))
AOI_BUFFER = AOI.buffer(CONFIG.get('AOI_BUFFER_METERS', 1000))
BBOX = AOI.bounds().coordinates().getInfo()[0]
CRS_TARGET = 'EPSG:4326'
MASTER_CRS = CONFIG.get('MASTER_CRS', 'EPSG:5070')
DATASET_ID = '01e'
DATASET = CONFIG.get('datasets', {}).get(DATASET_ID, {})
DATASET['drive_subfolder'] = '01_gee_rasters/' + DATASET.get('folder', '01e_era5_land')
MASTER_SCALE = int(CONFIG.get('MASTER_SCALE', {}).get(DATASET_ID, 1000))
LEAF = DRIVE_ROOT / DATASET['drive_subfolder']
ensure_layout(DRIVE_ROOT, DATASET['drive_subfolder'])
# Out:
# WindowsPath('Ogallala_Phase0/01_gee_rasters/01e_era5_land')

# %%
logger, LOG_PATH = configure_logger(NOTEBOOK_ID, DRIVE_ROOT)
REGISTRY = registry_path(DRIVE_ROOT)
@logged_step(NOTEBOOK_ID, DATASET['name'], DRIVE_ROOT, logger)
def logger_health_check() -> str:
    logger.info('Logger ready: %s', LOG_PATH)
    return str(LOG_PATH)
logger_health_check()
# Out:
# 2026-07-26 15:59:24,766 INFO Logger ready: Ogallala_Phase0\logs\01e_20260726T155924.log
# 'Ogallala_Phase0\\logs\\01e_20260726T155924.log'

# %%
DATASET_ID = '01e'
DATASET = {
  "name": "ERA5-Land",
  "asset_id": "ECMWF/ERA5_LAND/HOURLY",
  "vars": "MULTI",
  "bands": [
    "total_precipitation",
    "temperature_2m",
    "dewpoint_temperature_2m",
    "surface_net_solar_radiation"
  ],
  "scale": 1000,
  "kind": "collection",
  "start": "2002-01-01",
  "end": "2024-09-30",
  "folder": "01e_era5_land",
  "usage": "Meteorological controls for expected-function matching."
}
DATASET['drive_subfolder'] = '01_gee_rasters/01e_era5_land'
DATASET['crs'] = 'EPSG:5070'
DATASET['band_metadata'] = {band: {'long_name': band, 'units': '1', 'standard_name': 'unknown'} for band in DATASET['bands']}

# %%
def build_gee_source() -> tuple[object, bool]:
    """Build clipped, reprojected sources while retaining every native band."""
    asset_ids = DATASET['asset_id'] if isinstance(DATASET['asset_id'], list) else [DATASET['asset_id']]
    if DATASET['kind'] == 'image':
        return ee.Image(asset_ids[0]).clip(AOI), False
    sources = []
    for asset_id in asset_ids:
        collection = ee.ImageCollection(asset_id).filterBounds(AOI).filterDate(DATASET['start'], DATASET['end'])
        # Do not call select(): QA, uncertainty, and native metadata must survive.
        sources.append(collection.map(lambda image: image.clip(AOI).reproject(crs=MASTER_CRS, scale=MASTER_SCALE)))
    return (sources if DATASET['kind'] == 'collection_group' else sources[0]), True

SOURCE, IS_COLLECTION = build_gee_source()

# %%
# Client-side XEE pulls are disabled in local batch mode.
# Set DRY_RUN only to inspect configuration; it will not create a local NetCDF.
DRY_RUN_OUTPUTS: list[Path] = []
if DRY_RUN:
    logger.info('DRY_RUN is enabled; no Earth Engine export was submitted.')

# %%
def submit_normal_exports() -> list[str]:
    """Queue temporal or static exports without waiting for server completion."""
    if DRY_RUN:
        return []
    manager = BatchManager(DRIVE_ROOT, NOTEBOOK_ID, DATASET['name'], logger, max_concurrent=20)
    task_ids = []
    folder = f"Ogallala_Phase0/{DATASET['drive_subfolder']}/raw"
    sources = SOURCE if isinstance(SOURCE, list) else [SOURCE]
    for source_index, source in enumerate(sources):
        suffix = f'_part{source_index + 1}' if len(sources) > 1 else ''
        if IS_COLLECTION:
            start_year = int(DATASET['start'][:4])
            end_year = int(DATASET['end'][:4])
            for year in range(start_year, end_year + 1):
                start = f'{year}-01-01'
                end = f'{year + 1}-01-01'
                chunk = source.filterDate(start, end).median().clip(AOI)
                prefix = f"OG_{DATASET_ID}_{DATASET['vars']}{suffix}_{start}_{year}-12-31_{MASTER_SCALE}m"
                task_ids.append(manager.submit_image(chunk, f'{DATASET_ID}_{source_index}_{year}', folder, prefix, AOI, MASTER_SCALE, MASTER_CRS))
        else:
            start, end = DATASET['start'], DATASET['end']
            prefix = f"OG_{DATASET_ID}_{DATASET['vars']}{suffix}_{start}_{end}_{MASTER_SCALE}m"
            task_ids.append(manager.submit_image(source, f'{DATASET_ID}_{source_index}_static', folder, prefix, AOI, MASTER_SCALE, MASTER_CRS))
    return task_ids

QUEUED_TASKS = submit_normal_exports()
# Out:
# 2026-07-26 16:03:59,279 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:04:59,285 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:05:59,297 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:06:59,324 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:07:59,341 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:08:59,350 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:09:59,357 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:10:59,366 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:11:59,373 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:12:59,383 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:13:59,392 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:14:59,414 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:15:59,481 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:16:59,493 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:17:59,500 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:18:59,507 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:19:59,524 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:20:59,534 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:21:59,546 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:22:59,569 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:23:59,585 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:24:59,592 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:25:59,617 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:26:59,640 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:27:59,719 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:28:59,736 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:29:59,747 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:30:59,765 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:31:59,785 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:32:59,801 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:33:59,813 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:34:59,826 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:35:59,844 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:36:59,880 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:37:59,895 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:38:59,903 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:39:59,917 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:40:59,937 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:41:59,947 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:42:59,961 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:43:59,980 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:44:59,989 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:46:00,004 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:47:00,017 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:48:00,025 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:49:00,044 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:50:00,054 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:51:00,065 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:52:00,078 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:53:00,089 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:54:00,100 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:55:00,111 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:56:00,122 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:57:00,131 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:58:00,147 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:59:00,171 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:00:00,187 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:01:00,216 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:02:00,229 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:03:00,252 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:04:00,261 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:05:00,278 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:06:00,298 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:07:00,316 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:08:00,328 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:09:00,342 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:10:00,361 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:11:00,372 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:12:00,384 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:13:00,399 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:14:00,407 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:15:00,423 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:16:00,438 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:17:00,445 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:18:00,466 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:19:00,483 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:20:00,503 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:21:00,527 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:22:00,539 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:23:00,561 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:24:00,577 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:25:00,595 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:26:00,606 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:27:00,632 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:28:00,648 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:29:00,656 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:30:00,667 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:31:00,687 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:32:00,698 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:33:00,726 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:34:00,748 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:35:00,763 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:36:00,775 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:37:00,803 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:38:00,818 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:39:00,833 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:40:00,851 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:41:00,868 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:42:00,884 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:43:00,904 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:44:00,931 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:45:00,946 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:46:00,971 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:47:00,986 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:48:01,002 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:49:01,024 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:50:01,046 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:51:01,060 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:52:01,077 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:53:01,091 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:54:01,110 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:55:01,127 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:56:01,152 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:57:01,167 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:58:01,187 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 17:59:01,203 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:00:01,217 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:01:01,238 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:02:01,251 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:03:01,262 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:04:01,275 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:05:01,303 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:06:01,323 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:07:01,352 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:08:01,377 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:09:01,399 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:10:01,436 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:11:01,456 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:12:01,469 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:13:01,497 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:14:01,509 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:15:01,522 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:16:01,538 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:17:01,549 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:18:01,564 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:19:01,576 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:20:01,591 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:21:01,619 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:22:01,647 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:23:01,665 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:24:01,673 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:25:01,692 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:26:01,704 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:27:01,919 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:28:01,967 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:29:01,993 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:30:02,005 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:31:02,017 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:32:02,044 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:33:02,073 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:34:02,084 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:35:02,100 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:36:02,114 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:37:02,141 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:38:02,161 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:39:02,174 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:40:02,181 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:41:02,194 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:42:02,208 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:43:02,220 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:44:02,242 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:45:02,281 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:46:02,312 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:47:02,328 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:48:02,347 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:49:02,367 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:50:02,385 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:51:02,405 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:52:02,415 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:53:02,444 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:54:02,467 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:55:02,479 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:56:02,498 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:57:02,544 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:58:02,568 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 18:59:02,579 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:00:02,590 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:01:02,604 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:02:02,622 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:03:02,636 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:04:02,657 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:05:02,667 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:06:02,678 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:07:02,693 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:08:02,707 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:09:02,720 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:10:02,744 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:11:02,764 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:12:02,782 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:13:02,904 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:14:02,938 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:15:02,990 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:16:03,022 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:17:03,055 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:18:03,127 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:19:03,152 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:20:03,161 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:21:03,172 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:22:03,181 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:23:03,191 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:24:03,206 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:25:03,229 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:26:03,245 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:27:03,280 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:28:03,297 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:29:03,311 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:30:03,321 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:31:03,360 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:32:03,378 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:33:03,392 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:34:03,403 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:35:03,428 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:36:03,441 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:37:03,453 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:38:03,470 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:39:03,494 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:40:03,515 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:41:03,553 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:42:03,563 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:43:03,577 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:44:03,584 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:45:03,606 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:46:03,617 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:47:03,644 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:48:03,692 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:49:03,710 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:50:03,724 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:51:03,751 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:52:03,770 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:53:03,780 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:54:03,802 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:55:03,818 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:56:03,830 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:57:03,853 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:58:03,873 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 19:59:03,883 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:00:03,913 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:01:03,925 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:02:03,933 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:03:03,945 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:04:03,957 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:05:03,984 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:06:03,999 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:07:04,011 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:08:04,065 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:09:04,077 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:10:04,099 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:11:04,112 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:12:04,135 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:13:04,157 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:14:04,171 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:15:04,183 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:16:04,204 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:17:04,224 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:18:04,256 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:19:04,269 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:20:04,282 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:21:04,293 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:22:04,302 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:23:04,308 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:24:04,330 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:25:04,347 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:26:04,362 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:27:04,374 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:28:04,385 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:29:04,441 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:30:04,454 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:31:04,465 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:32:04,476 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:33:04,492 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:34:04,505 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:35:04,511 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:36:04,523 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:37:04,533 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:38:04,543 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:39:04,549 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:40:04,556 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:41:04,569 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:42:04,586 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:43:04,600 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:44:04,622 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:45:04,628 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:46:04,640 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:47:04,660 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:48:04,681 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:49:04,688 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:50:04,695 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:51:04,706 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:52:04,720 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:53:04,749 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:54:04,767 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:55:04,813 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:56:04,847 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:57:04,855 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:58:04,864 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 20:59:04,891 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:00:04,904 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:01:04,920 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:02:04,937 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:03:04,945 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:04:04,959 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:05:04,973 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:06:04,990 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:07:05,024 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:08:05,055 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:09:05,072 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:10:05,084 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:11:05,097 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:12:05,108 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:13:05,125 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:14:05,142 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:15:05,159 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:16:05,185 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:17:05,203 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:18:05,236 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:19:05,253 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:20:05,272 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:21:05,285 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:22:05,303 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:23:05,313 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:24:05,324 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:25:05,334 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:26:05,356 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:27:05,373 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:28:05,389 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:29:05,408 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:30:05,421 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:31:05,442 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:32:05,457 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:33:05,485 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:34:05,497 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:35:05,529 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:36:05,549 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:37:05,566 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:38:05,580 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:39:05,595 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:40:05,608 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:41:05,618 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:42:05,635 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:43:05,650 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:44:05,666 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:45:05,677 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:46:05,752 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:47:05,764 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:48:05,777 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:49:05,784 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:50:05,792 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:51:05,809 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:52:05,821 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:53:05,832 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:54:05,846 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:55:05,858 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:56:05,874 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:57:05,887 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:58:05,901 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 21:59:05,918 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:00:05,940 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:01:05,948 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:02:05,958 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:03:05,971 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:04:05,991 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:05:06,015 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:06:06,026 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:07:06,088 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:08:06,104 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:09:06,126 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:10:06,144 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:11:06,158 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:12:06,164 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:13:06,182 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:14:06,192 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:15:06,205 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:16:06,222 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:17:06,241 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:18:06,257 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:19:06,292 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:20:06,325 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:21:06,342 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:22:06,355 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:23:06,367 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:24:06,395 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:25:06,410 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:26:06,419 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:27:06,433 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:28:06,448 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:29:06,456 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:30:06,475 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:31:06,485 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:32:06,493 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:33:06,511 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:34:06,528 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:35:06,540 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:36:06,557 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:37:06,576 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:38:06,599 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:39:06,625 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:40:06,638 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:41:06,647 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:42:06,659 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:43:06,682 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:44:06,691 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:45:06,729 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:46:06,743 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:47:06,783 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:48:06,805 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:49:06,815 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:50:06,827 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:51:06,850 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:52:06,866 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:53:06,879 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:54:06,899 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:55:06,919 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:56:06,932 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:57:06,943 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:58:06,957 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 22:59:06,966 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:00:06,981 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:01:06,997 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:02:07,011 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:03:07,027 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:04:07,053 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:05:07,066 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:06:07,090 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:07:07,104 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:08:07,122 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:09:07,138 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:10:07,144 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:11:07,159 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:12:07,172 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:13:07,184 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:14:07,198 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:15:07,218 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:16:07,232 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:17:07,240 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:18:07,247 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:19:07,266 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:20:07,283 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:21:07,308 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:22:07,322 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:23:07,341 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:24:07,365 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:25:07,376 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:26:07,396 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:27:07,408 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:28:07,435 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:29:07,452 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:30:07,469 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:31:07,481 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:32:07,506 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:33:07,523 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:34:07,539 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:35:07,550 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:36:07,556 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:37:07,562 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:38:07,577 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:39:07,592 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:40:07,603 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:41:07,620 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:42:07,643 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:43:07,663 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:44:07,675 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:45:07,685 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:46:07,704 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:47:07,718 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:48:07,729 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:49:07,743 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:50:07,779 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:51:07,789 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:52:07,808 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:53:07,826 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:54:07,847 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:55:07,864 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:56:07,876 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:57:07,885 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:58:07,895 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 23:59:07,955 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:00:07,976 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:01:07,985 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:02:08,135 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:03:08,195 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:04:08,218 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:05:08,231 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:06:08,240 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:07:08,253 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:08:08,266 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:09:08,281 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:10:08,288 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:11:08,299 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:12:08,306 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:13:08,316 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:14:08,327 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:15:08,340 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:16:08,347 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:17:08,367 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:18:08,402 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:19:08,408 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:20:08,422 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:21:08,437 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:22:08,444 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:23:08,454 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:24:08,460 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:25:08,479 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:26:08,486 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:27:08,500 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:28:08,512 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:29:08,522 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:30:08,543 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:31:08,550 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:32:08,561 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:33:08,573 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:34:08,584 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:35:08,595 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:36:08,607 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:37:08,613 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:38:08,623 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:39:08,646 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:40:08,656 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:41:08,666 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:42:08,675 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:43:08,693 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:44:08,702 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:45:08,718 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:46:08,725 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:47:08,740 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:48:08,764 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:49:08,776 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:50:08,786 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:51:08,800 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:52:08,945 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:53:08,970 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:54:08,985 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:55:09,004 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:56:09,014 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:57:09,026 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:58:09,056 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 00:59:09,079 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:00:09,094 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:01:09,111 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:02:09,122 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:03:09,130 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:04:09,156 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:05:09,167 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:06:09,174 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:07:09,188 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:08:09,203 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:09:09,220 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:10:09,229 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:11:09,237 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:12:09,250 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:13:09,259 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:14:09,268 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:15:09,277 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:16:09,304 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:17:09,316 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:18:09,328 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:19:09,334 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:20:09,342 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:21:09,359 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:22:09,373 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:23:09,390 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:24:09,404 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:25:09,416 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:26:09,424 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:27:09,428 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:28:09,471 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:29:09,485 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:30:09,511 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:31:09,537 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:32:09,544 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:33:09,565 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:34:09,590 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:35:09,602 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:36:09,618 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:37:09,646 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:38:09,662 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:39:09,673 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:40:09,692 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:41:09,700 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:42:09,716 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:43:09,725 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:44:09,740 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:45:09,749 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:46:09,759 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:47:09,776 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:48:09,795 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:49:09,803 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:50:09,813 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:51:09,820 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:52:09,846 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:53:09,853 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:54:09,862 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:55:09,879 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:56:09,897 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:57:09,922 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:58:09,930 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 01:59:09,936 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:00:09,952 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:01:09,964 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:02:09,976 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:03:09,983 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:04:09,995 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:05:10,008 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:06:10,028 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:07:10,040 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:08:10,047 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:09:10,060 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:10:10,066 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:11:10,076 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:12:10,088 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:13:10,097 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:14:10,114 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:15:10,135 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:16:10,159 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:17:10,173 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:18:10,185 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:19:10,195 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:20:10,210 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:21:10,228 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:22:10,240 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:23:10,262 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:24:10,282 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:25:10,302 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:26:10,327 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:27:10,349 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:28:10,367 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:29:10,373 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:30:10,385 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:31:10,398 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:32:10,416 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:33:10,430 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:34:10,443 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:35:10,451 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:36:10,465 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:37:10,478 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:38:10,494 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:39:10,502 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:40:10,527 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:41:10,553 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:42:10,564 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:43:10,577 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:44:10,588 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:45:10,595 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:46:10,620 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:47:10,630 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:48:10,642 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:49:10,668 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:50:10,680 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:51:10,697 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:52:10,711 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:53:10,722 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:54:10,742 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:55:10,751 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:56:10,760 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:57:10,770 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:58:10,790 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 02:59:10,806 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:00:10,818 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:01:10,830 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:02:10,857 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:03:10,866 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:04:10,877 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:05:10,914 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:06:10,929 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:07:10,949 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:08:10,962 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:09:10,996 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:10:11,014 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:11:11,030 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:12:11,049 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:13:11,065 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:14:11,079 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:15:11,105 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:16:11,122 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:17:11,144 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:18:11,159 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:19:11,224 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:20:11,245 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:21:11,260 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:22:11,285 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:23:11,300 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:24:11,311 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:25:11,319 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:26:11,335 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:27:11,348 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:28:11,362 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:29:11,372 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:30:11,375 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:31:11,387 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:32:11,408 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:33:11,418 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:34:11,427 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:35:11,433 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:36:11,442 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:37:11,454 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 03:38:11,469 INFO Active cap reached; sleeping 60 seconds
# ...
# 2026-07-27 05:40:13,050 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:41:13,069 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:42:13,096 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:43:13,109 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:44:13,121 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:45:13,134 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:46:13,145 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:47:13,162 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:48:13,179 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:49:13,192 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:50:13,203 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:51:13,213 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:52:13,241 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:53:13,253 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:54:13,260 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:55:13,267 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:56:13,278 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:57:13,284 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:58:13,295 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 05:59:13,301 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:00:13,311 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:01:13,321 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:02:13,331 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:03:13,336 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:04:13,345 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:05:13,350 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:06:13,363 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:07:13,381 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:08:13,398 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:09:13,429 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:10:13,436 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:11:13,446 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:12:13,461 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:13:13,481 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:14:13,496 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:15:13,505 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:16:13,517 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:17:13,537 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:18:13,593 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:19:13,599 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:20:13,609 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:21:13,621 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:22:13,629 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:23:13,637 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:24:13,650 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:25:13,661 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:26:13,671 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:27:13,687 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:28:13,699 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:29:13,708 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:30:13,720 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:31:13,736 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:32:13,753 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:33:13,762 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:34:13,773 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:35:13,795 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:36:13,814 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:37:13,825 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:38:13,841 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:39:13,853 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:40:13,860 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:41:13,873 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:42:13,880 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:43:13,894 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:44:13,901 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:45:13,911 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:46:13,943 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:47:13,951 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:48:13,965 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:49:13,973 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:50:13,980 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:51:13,994 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:52:14,003 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:53:14,016 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:54:14,028 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:55:14,041 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:56:14,057 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:57:14,073 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:58:14,085 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 06:59:14,094 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:00:14,105 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:01:14,126 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:02:14,143 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:03:14,155 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:04:14,175 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:05:14,183 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:06:14,207 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:07:14,225 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:08:14,250 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:09:14,258 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:10:14,264 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:11:14,278 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:12:14,293 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:13:14,305 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:14:14,315 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:15:14,323 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:16:14,328 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:17:14,338 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:18:14,346 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:19:14,358 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:20:14,369 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:21:14,392 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:22:14,406 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:23:14,426 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:24:14,447 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:25:14,453 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:26:14,464 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:27:14,473 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:28:14,483 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:29:14,498 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:30:14,514 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:31:14,521 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:32:14,530 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:33:14,537 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:34:14,547 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:35:14,564 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:36:14,575 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:37:14,587 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:38:14,593 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:39:14,610 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:40:14,617 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:41:14,633 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:42:14,644 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:43:14,662 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:44:14,678 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:45:14,695 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:46:14,706 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:47:14,718 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:48:14,736 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:49:14,748 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:50:14,783 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:51:14,795 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:52:14,809 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:53:14,831 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:54:14,852 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:55:14,868 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:56:14,879 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:57:14,901 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:58:14,912 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:59:14,924 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:00:14,936 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:01:14,950 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:02:14,960 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:03:14,967 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:04:14,977 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:05:14,985 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:06:15,003 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:07:15,012 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:08:15,031 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:09:15,041 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:10:15,053 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:11:15,082 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:12:15,091 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:13:15,108 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:14:15,118 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:15:15,144 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:16:15,159 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:17:15,176 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:18:15,208 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:19:15,233 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:20:15,245 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:21:15,258 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:22:15,274 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:23:15,280 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:24:15,297 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:25:15,305 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:26:15,324 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:27:15,333 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:28:15,354 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:29:15,372 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:30:15,386 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:31:15,394 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:32:15,411 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:33:15,431 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:34:15,447 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:35:15,464 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:36:15,496 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:37:15,513 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:38:15,522 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:39:15,531 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:40:15,543 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:41:15,549 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:42:15,559 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:43:15,574 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:44:15,579 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:45:15,597 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:46:15,611 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:47:15,630 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:48:15,657 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:49:15,672 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:50:15,678 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:51:15,684 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:52:15,703 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:53:15,719 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:54:15,729 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:55:15,747 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:56:15,753 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:57:15,760 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:58:15,769 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:59:15,780 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:00:15,797 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:01:15,808 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:02:15,825 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:03:15,834 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:04:15,851 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:05:15,863 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:06:15,878 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:07:15,895 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:08:15,910 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:09:15,922 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:10:15,933 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:11:15,947 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:12:15,964 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:13:15,984 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:14:15,992 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:15:16,012 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:16:16,027 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:17:16,034 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:18:16,057 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:19:16,075 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:20:16,094 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:21:16,104 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:22:16,119 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:23:16,136 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:24:16,148 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:25:16,162 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:26:16,176 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:27:16,248 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:28:16,272 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:29:16,280 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:32:34,289 INFO Active cap reached; sleeping 60 seconds

# %%
# %pip -q install compliance-checker
MAX_CONCURRENT = 20
MAX_DAILY_TASKS = 2500
# BatchManager enforces the local cap, retry backoff, registry writes, and non-blocking submission.

# %%
# GeoTIFFs remain in Google Drive as server-side export results.
# No local GeoTIFF-to-CF conversion is performed by this notebook.

# %%
OUTPUTS = list(DRY_RUN_OUTPUTS)
for output in OUTPUTS:
    write_manifest(DRIVE_ROOT, NOTEBOOK_ID, [output], DATASET['name'])

# %%
registry = pd.read_csv(registry_path(DRIVE_ROOT))
status = 'DRY_RUN_NO_EXPORT' if DRY_RUN else ('QUEUED' if QUEUED_TASKS else 'FAILED_OR_NOT_RUN')
print(pd.DataFrame([{'dataset': DATASET['name'], 'earth_engine_tasks': len(QUEUED_TASKS), 'status': status}]).to_string(index=False))
