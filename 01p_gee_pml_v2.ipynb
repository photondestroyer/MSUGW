# %% [markdown]
# # 01p: PML-V2 ET
#
# **Why:** Longer evaporative-response record.
#
# - Asset ID: `projects/sat-io/open-datasets/PML_V2`
# - Outputs: server-side GeoTIFF tasks in Google Drive folder `raw/`; local logs and task registry under `DRIVE_ROOT`
# - Author: `<name / institution>`
# - This notebook runs locally, preserves native bands and QA values, and does not select away quality metadata.

# %%
# Local bootstrap. Installs are quiet so the notebook stays readable.
# %pip -q install earthengine-api xee xarray netCDF4 h5netcdf geopandas rioxarray regionmask "dask[diagnostics]" requests tqdm python-dotenv pyyaml matplotlib pandas pyproj shapely compliance-checker
from pathlib import Path
import os, sys, json, time, logging, traceback
from datetime import datetime

PROJECT_ID = os.getenv("GEE_PROJECT", "ee-ishansinhagzb")
import ee
ee.Authenticate()
ee.Initialize(project=PROJECT_ID)

# Local files hold configuration, logs, and task metadata. GeoTIFF outputs go to Google Drive via EE.
DRIVE_ROOT = Path(os.getenv("OGALLALA_PHASE0_ROOT", "./Ogallala_Phase0"))
SETUP_DIR = DRIVE_ROOT / '00_setup'
SETUP_DIR.mkdir(parents=True, exist_ok=True)
UTILS_SOURCE = '"""Shared utilities for the Ogallala Phase 0 Colab notebooks."""\nfrom __future__ import annotations\n\nimport json\nimport logging\nimport math\nimport os\nimport time\nimport traceback\nfrom datetime import datetime, timezone\nfrom functools import wraps\nfrom pathlib import Path\nfrom typing import Any, Callable, Iterable\n\nimport numpy as np\nimport pandas as pd\n\nREGISTRY_COLUMNS = [\n    "timestamp", "notebook_id", "dataset", "task_id_or_file", "pathway",\n    "status", "start_time", "end_time", "n_bytes", "error_message", "retries",\n]\nTERMINAL = {"COMPLETED", "FAILED"}\n\n\ndef utc_now() -> str:\n    """Return an ISO-8601 UTC timestamp."""\n    return datetime.now(timezone.utc).isoformat()\n\n\ndef ensure_layout(root: Path, leaf: str) -> Path:\n    """Create the standard Drive tree and return one dataset leaf."""\n    root = Path(root)\n    for path in [root / "00_setup", root / "logs", root / "manifests"]:\n        path.mkdir(parents=True, exist_ok=True)\n    for name in ["raw", "cf", "qc"]:\n        (root / leaf / name).mkdir(parents=True, exist_ok=True)\n    registry = root / "logs" / "task_registry.csv"\n    if not registry.exists():\n        pd.DataFrame(columns=REGISTRY_COLUMNS).to_csv(registry, index=False)\n    return root / leaf\n\n\ndef configure_logger(notebook_id: str, root: Path) -> tuple[logging.Logger, Path]:\n    """Configure rotating file and stdout logging for a notebook."""\n    from logging.handlers import RotatingFileHandler\n    log_dir = Path(root) / "logs"\n    log_dir.mkdir(parents=True, exist_ok=True)\n    path = log_dir / f"{notebook_id}_{datetime.now().strftime(\'%Y%m%dT%H%M%S\')}.log"\n    logger = logging.getLogger(notebook_id)\n    logger.setLevel(logging.INFO)\n    logger.handlers.clear()\n    formatter = logging.Formatter("%(asctime)s %(levelname)s %(message)s")\n    file_handler = RotatingFileHandler(path, maxBytes=50 * 1024 * 1024, backupCount=3)\n    file_handler.setFormatter(formatter)\n    stream_handler = logging.StreamHandler()\n    stream_handler.setFormatter(formatter)\n    logger.addHandler(file_handler)\n    logger.addHandler(stream_handler)\n    return logger, path\n\n\ndef registry_path(root: Path) -> Path:\n    """Return the shared task registry path."""\n    path = Path(root) / "logs" / "task_registry.csv"\n    path.parent.mkdir(parents=True, exist_ok=True)\n    if not path.exists():\n        pd.DataFrame(columns=REGISTRY_COLUMNS).to_csv(path, index=False)\n    return path\n\n\ndef append_registry(root: Path, **values: Any) -> None:\n    """Append a normalized task or file event to the registry."""\n    row = {column: values.get(column, "") for column in REGISTRY_COLUMNS}\n    row["timestamp"] = row["timestamp"] or utc_now()\n    path = registry_path(root)\n    frame = pd.DataFrame([row], columns=REGISTRY_COLUMNS)\n    frame.to_csv(path, mode="a", header=path.stat().st_size == 0, index=False)\n\n\ndef logged_step(notebook_id: str, dataset: str, root: Path, logger: logging.Logger) -> Callable:\n    """Decorate an I/O step so failures are logged and recorded."""\n    def decorator(function: Callable) -> Callable:\n        @wraps(function)\n        def wrapper(*args: Any, **kwargs: Any) -> Any:\n            start = utc_now()\n            try:\n                result = function(*args, **kwargs)\n                append_registry(root, notebook_id=notebook_id, dataset=dataset,\n                                task_id_or_file=function.__name__, pathway="xee",\n                                status="COMPLETED", start_time=start, end_time=utc_now())\n                return result\n            except Exception as exc:\n                logger.error("%s failed: %s\\n%s", function.__name__, exc, traceback.format_exc())\n                append_registry(root, notebook_id=notebook_id, dataset=dataset,\n                                task_id_or_file=function.__name__, pathway="xee",\n                                status="FAILED", start_time=start, end_time=utc_now(),\n                                error_message=str(exc))\n                return None\n        return wrapper\n    return decorator\n\n\nclass BatchManager:\n    """Submit non-blocking Earth Engine exports under a small concurrency cap."""\n\n    def __init__(self, root: Path, notebook_id: str, dataset: str,\n                 logger: logging.Logger, max_concurrent: int = 20,\n                 max_daily_tasks: int = 2500) -> None:\n        self.root = Path(root)\n        self.notebook_id = notebook_id\n        self.dataset = dataset\n        self.logger = logger\n        self.max_concurrent = max_concurrent\n        self.max_daily_tasks = max_daily_tasks\n\n    def active_count(self) -> int:\n        """Count locally registered active submissions."""\n        frame = pd.read_csv(registry_path(self.root))\n        if frame.empty:\n            return 0\n        return int(frame["status"].isin(["STARTED", "RUNNING"]).sum())\n\n    def wait_for_slot(self) -> None:\n        """Wait before submitting when the local active cap is reached."""\n        while self.active_count() >= self.max_concurrent:\n            self.logger.info("Active cap reached; sleeping 60 seconds")\n            time.sleep(60)\n\n    def start(self, task: Any, description: str, retries: int = 3) -> str:\n        """Start a task with retry backoff and return its Earth Engine ID."""\n        self.wait_for_slot()\n        delays = [10, 60, 300]\n        start_time = utc_now()\n        for attempt in range(retries + 1):\n            try:\n                task.start()\n                task_id = getattr(task, "id", "") or task.status().get("id", "")\n                append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                task_id_or_file=task_id, pathway="batch", status="STARTED",\n                                start_time=start_time, retries=attempt)\n                time.sleep(2)\n                return task_id\n            except Exception as exc:\n                message = str(exc).lower()\n                retryable = "429" in message or "rate limit" in message or "quota" in message\n                if not retryable or attempt >= retries:\n                    append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                    task_id_or_file=description, pathway="batch", status="FAILED",\n                                    start_time=start_time, end_time=utc_now(),\n                                    error_message=str(exc), retries=attempt)\n                    self.logger.error("Export failed: %s", exc)\n                    return ""\n                delay = delays[min(attempt, len(delays) - 1)]\n                self.logger.warning("Rate limit on %s; retrying in %ss", description, delay)\n                append_registry(self.root, notebook_id=self.notebook_id, dataset=self.dataset,\n                                task_id_or_file=description, pathway="batch", status="RETRIED",\n                                start_time=start_time, retries=attempt + 1,\n                                error_message=str(exc))\n                time.sleep(delay)\n        return ""\n\n    def submit_image(self, image: Any, description: str, folder: str,\n                     prefix: str, region: Any, scale: int, crs: str) -> str:\n        """Create and start a Drive GeoTIFF export without polling."""\n        import ee\n        task = ee.batch.Export.image.toDrive(\n            image=image, description=description, folder=folder,\n            fileNamePrefix=prefix, region=region, scale=scale, crs=crs,\n            maxPixels=1e13, fileFormat="GeoTIFF",\n        )\n        return self.start(task, description)\n\n    def monitor_once(self) -> pd.DataFrame:\n        """Poll registered Earth Engine tasks once and update their statuses."""\n        import ee\n        path = registry_path(self.root)\n        frame = pd.read_csv(path)\n        if frame.empty:\n            return frame\n        for index, row in frame.iterrows():\n            if row["status"] not in ["STARTED", "RUNNING"] or not row["task_id_or_file"]:\n                continue\n            try:\n                status = ee.data.getTaskStatus(str(row["task_id_or_file"]))[0]\n                state = status.get("state", "UNKNOWN")\n                mapped = {"READY": "RUNNING", "RUNNING": "RUNNING",\n                          "COMPLETED": "COMPLETED", "FAILED": "FAILED",\n                          "CANCELLED": "FAILED"}.get(state, state)\n                frame.loc[index, "status"] = mapped\n                frame.loc[index, "end_time"] = utc_now() if mapped in TERMINAL else ""\n                frame.loc[index, "error_message"] = status.get("error_message", "")\n            except Exception as exc:\n                self.logger.warning("Could not poll %s: %s", row["task_id_or_file"], exc)\n        frame.to_csv(path, index=False)\n        return frame\n\n\ndef normalize_projected_dataset(ds: Any, crs: str = "EPSG:5070") -> Any:\n    """Normalize raster dimensions and add projected CF coordinates."""\n    import xarray as xr\n    if "lat" in ds.dims and "y" not in ds.dims:\n        ds = ds.rename({"lat": "y"})\n    if "lon" in ds.dims and "x" not in ds.dims:\n        ds = ds.rename({"lon": "x"})\n    if "y" not in ds.coords:\n        ds = ds.assign_coords(y=np.arange(ds.sizes.get("y", 1), dtype=float))\n    if "x" not in ds.coords:\n        ds = ds.assign_coords(x=np.arange(ds.sizes.get("x", 1), dtype=float))\n    ds["y"].attrs.update({"standard_name": "projection_y_coordinate", "units": "m", "axis": "Y"})\n    ds["x"].attrs.update({"standard_name": "projection_x_coordinate", "units": "m", "axis": "X"})\n    if "lat" not in ds:\n        ds["lat"] = xr.DataArray(np.broadcast_to(ds["y"].values[:, None],\n                                                  (ds.sizes["y"], ds.sizes["x"])), dims=("y", "x"))\n    if "lon" not in ds:\n        ds["lon"] = xr.DataArray(np.broadcast_to(ds["x"].values[None, :],\n                                                  (ds.sizes["y"], ds.sizes["x"])), dims=("y", "x"))\n    ds["lat"].attrs.update({"standard_name": "latitude", "units": "degrees_north"})\n    ds["lon"].attrs.update({"standard_name": "longitude", "units": "degrees_east"})\n    return ds\n\n\ndef write_cf_netcdf(ds: Any, path: Path, attrs: dict[str, Any],\n                    variable_attrs: dict[str, dict[str, Any]] | None = None) -> Path:\n    """Write a compressed projected NetCDF with the Phase 0 CF contract."""\n    import xarray as xr\n    path = Path(path)\n    path.parent.mkdir(parents=True, exist_ok=True)\n    ds = normalize_projected_dataset(ds)\n    ds.attrs.update({\n        "Conventions": "CF-1.8", "title": attrs.get("title", "Ogallala Phase 0 dataset"),\n        "history": f"{utc_now()} notebook={attrs.get(\'notebook_id\', \'unknown\')} git_commit=placeholder",\n        "institution": attrs.get("institution", "Ogallala Phase 0 research team"),\n        "source": attrs.get("source", "Google Earth Engine"),\n        "gee_asset_id": attrs.get("gee_asset_id", ""),\n        "references": attrs.get("references", "Groundwater Buffering of Ecosystem Function During Drought Phase 0 plan"),\n        "comment": attrs.get("comment", "Master grid: EPSG:5070; native bands and QA bands preserved."),\n        "featureType": attrs.get("featureType", "grid"),\n    })\n    ds["crs"] = xr.DataArray(0, attrs={\n        "grid_mapping_name": "albers_conical_equal_area", "semi_major_axis": 6378137.0,\n        "inverse_flattening": 298.257222101, "false_easting": 0.0, "false_northing": 0.0,\n        "spatial_ref": crs_wkt(),\n    })\n    variable_attrs = variable_attrs or {}\n    for name, variable in ds.data_vars.items():\n        if name == "crs":\n            continue\n        defaults = {"long_name": name, "units": "1", "_FillValue": -9999.0,\n                    "grid_mapping": "crs", "coordinates": "lat lon"}\n        defaults.update(variable_attrs.get(name, {}))\n        variable.attrs.update(defaults)\n    encoding: dict[str, dict[str, Any]] = {}\n    for name, variable in ds.data_vars.items():\n        if name == "crs":\n            continue\n        fill = variable.attrs.get("_FillValue", -9999.0)\n        encoding[name] = {"zlib": True, "complevel": 4, "_FillValue": fill}\n        if "time" in variable.dims:\n            encoding[name]["chunksizes"] = tuple(min(24, ds.sizes[d]) for d in variable.dims)\n    if "time" in ds.coords:\n        ds["time"].attrs.update({"standard_name": "time", "long_name": "time",\n                                  "units": "days since 1970-01-01 00:00:00",\n                                  "calendar": "proleptic_gregorian", "axis": "T"})\n        encoding["time"] = {"units": "days since 1970-01-01 00:00:00",\n                             "calendar": "proleptic_gregorian"}\n    ds.to_netcdf(path, format="NETCDF4_CLASSIC", engine="netcdf4", encoding=encoding)\n    return path\n\n\ndef crs_wkt() -> str:\n    """Return a WKT representation for the master Albers grid."""\n    try:\n        from pyproj import CRS\n        return CRS.from_epsg(5070).to_wkt()\n    except Exception:\n        return "EPSG:5070"\n\n\ndef qc_netcdf(path: Path, qc_dir: Path) -> dict[str, Any]:\n    """Create summary statistics and a quicklook for a NetCDF file."""\n    import matplotlib.pyplot as plt\n    import xarray as xr\n    path, qc_dir = Path(path), Path(qc_dir)\n    qc_dir.mkdir(parents=True, exist_ok=True)\n    ds = xr.open_dataset(path)\n    summary: dict[str, Any] = {}\n    for name, value in ds.data_vars.items():\n        if name == "crs":\n            continue\n        array = value.values.astype(float)\n        finite = array[np.isfinite(array)]\n        summary[name] = {"min": float(np.min(finite)) if finite.size else None,\n                         "max": float(np.max(finite)) if finite.size else None,\n                         "mean": float(np.mean(finite)) if finite.size else None,\n                         "std": float(np.std(finite)) if finite.size else None,\n                         "n_valid": int(finite.size)}\n        if finite.size:\n            image = np.nanmean(array, axis=0) if "time" in value.dims else array\n            plt.imsave(qc_dir / f"{path.stem}_{name}.png", image, cmap="viridis")\n    summary_path = qc_dir / f"{path.stem}_summary_stats.json"\n    summary_path.write_text(json.dumps(summary, indent=2), encoding="utf-8")\n    ds.close()\n    return summary\n\n\ndef write_manifest(root: Path, notebook_id: str, files: Iterable[Path],\n                   dataset: str, status: str = "COMPLETED") -> Path:\n    """Write provenance metadata for files produced by one notebook."""\n    entries = []\n    for file_path in files:\n        file_path = Path(file_path)\n        if file_path.exists():\n            entries.append({"file": str(file_path), "size_bytes": file_path.stat().st_size,\n                            "cf_version": "CF-1.8", "dataset": dataset})\n    path = Path(root) / "manifests" / f"{notebook_id}_manifest.json"\n    path.parent.mkdir(parents=True, exist_ok=True)\n    path.write_text(json.dumps({"notebook_id": notebook_id, "status": status,\n                                "files": entries}, indent=2), encoding="utf-8")\n    return path\n'
(SETUP_DIR / 'utils.py').write_text(UTILS_SOURCE, encoding='utf-8')
sys.path.insert(0, str(SETUP_DIR))
from utils import *
NOTEBOOK_ID = '01p'
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

CONFIG_PATH = DRIVE_ROOT / '00_setup' / 'config.yaml'
if not CONFIG_PATH.exists():
    raise FileNotFoundError('Run 00_setup_aoi_and_config.ipynb first to create config.yaml and the AOI.')
CONFIG = yaml.safe_load(CONFIG_PATH.read_text(encoding='utf-8'))
DRY_RUN = bool(CONFIG.get('DRY_RUN', False))
AOI = ee.Geometry(json.loads((DRIVE_ROOT / '00_setup' / 'aoi_ee_geometry.json').read_text()))
AOI_BUFFER = AOI.buffer(CONFIG.get('AOI_BUFFER_METERS', 1000))
BBOX = AOI.bounds().coordinates().getInfo()[0]
CRS_TARGET = 'EPSG:4326'
MASTER_CRS = CONFIG.get('MASTER_CRS', 'EPSG:5070')
DATASET_ID = '01p'
DATASET = CONFIG.get('datasets', {}).get(DATASET_ID, {})
DATASET['drive_subfolder'] = '01_gee_rasters/' + DATASET.get('folder', '01p_pml_v2')
MASTER_SCALE = int(CONFIG.get('MASTER_SCALE', {}).get(DATASET_ID, 1000))
LEAF = DRIVE_ROOT / DATASET['drive_subfolder']
ensure_layout(DRIVE_ROOT, DATASET['drive_subfolder'])
# Out:
# WindowsPath('Ogallala_Phase0/01_gee_rasters/01p_pml_v2')

# %%
logger, LOG_PATH = configure_logger(NOTEBOOK_ID, DRIVE_ROOT)
REGISTRY = registry_path(DRIVE_ROOT)
@logged_step(NOTEBOOK_ID, DATASET['name'], DRIVE_ROOT, logger)
def logger_health_check() -> str:
    logger.info('Logger ready: %s', LOG_PATH)
    return str(LOG_PATH)
logger_health_check()
# Out:
# 2026-07-26 16:02:41,684 INFO Logger ready: Ogallala_Phase0\logs\01p_20260726T160241.log
# 'Ogallala_Phase0\\logs\\01p_20260726T160241.log'

# %%
DATASET_ID = '01p'
DATASET = {
  "name": "PML-V2 ET",
  "asset_id": "projects/sat-io/open-datasets/PML_V2",
  "vars": "ET",
  "bands": [
    "Ec",
    "Es",
    "Ei",
    "ET_water",
    "ET"
  ],
  "scale": 1000,
  "kind": "collection",
  "start": "2000-01-01",
  "end": "2023-12-31",
  "folder": "01p_pml_v2",
  "usage": "Longer evaporative-response record."
}
DATASET['drive_subfolder'] = '01_gee_rasters/01p_pml_v2'
DATASET['crs'] = 'EPSG:5070'
DATASET['band_metadata'] = {band: {'long_name': band, 'units': '1', 'standard_name': 'unknown'} for band in DATASET['bands']}

# %%
def build_gee_source() -> tuple[object, bool]:
    """Build clipped, reprojected sources while retaining every native band."""
    asset_ids = DATASET['asset_id'] if isinstance(DATASET['asset_id'], list) else [DATASET['asset_id']]
    if DATASET['kind'] == 'image':
        return ee.Image(asset_ids[0]).clip(AOI), False
    sources = []
    for asset_id in asset_ids:
        collection = ee.ImageCollection(asset_id).filterBounds(AOI).filterDate(DATASET['start'], DATASET['end'])
        # Do not call select(): QA, uncertainty, and native metadata must survive.
        sources.append(collection.map(lambda image: image.clip(AOI).reproject(crs=MASTER_CRS, scale=MASTER_SCALE)))
    return (sources if DATASET['kind'] == 'collection_group' else sources[0]), True

SOURCE, IS_COLLECTION = build_gee_source()

# %%
# Client-side XEE pulls are disabled in local batch mode.
# Set DRY_RUN only to inspect configuration; it will not create a local NetCDF.
DRY_RUN_OUTPUTS: list[Path] = []
if DRY_RUN:
    logger.info('DRY_RUN is enabled; no Earth Engine export was submitted.')

# %%
def submit_normal_exports() -> list[str]:
    """Queue temporal or static exports without waiting for server completion."""
    if DRY_RUN:
        return []
    manager = BatchManager(DRIVE_ROOT, NOTEBOOK_ID, DATASET['name'], logger, max_concurrent=20)
    task_ids = []
    folder = f"Ogallala_Phase0/{DATASET['drive_subfolder']}/raw"
    sources = SOURCE if isinstance(SOURCE, list) else [SOURCE]
    for source_index, source in enumerate(sources):
        suffix = f'_part{source_index + 1}' if len(sources) > 1 else ''
        if IS_COLLECTION:
            start_year = int(DATASET['start'][:4])
            end_year = int(DATASET['end'][:4])
            for year in range(start_year, end_year + 1):
                start = f'{year}-01-01'
                end = f'{year + 1}-01-01'
                chunk = source.filterDate(start, end).median().clip(AOI)
                prefix = f"OG_{DATASET_ID}_{DATASET['vars']}{suffix}_{start}_{year}-12-31_{MASTER_SCALE}m"
                task_ids.append(manager.submit_image(chunk, f'{DATASET_ID}_{source_index}_{year}', folder, prefix, AOI, MASTER_SCALE, MASTER_CRS))
        else:
            start, end = DATASET['start'], DATASET['end']
            prefix = f"OG_{DATASET_ID}_{DATASET['vars']}{suffix}_{start}_{end}_{MASTER_SCALE}m"
            task_ids.append(manager.submit_image(source, f'{DATASET_ID}_{source_index}_static', folder, prefix, AOI, MASTER_SCALE, MASTER_CRS))
    return task_ids

QUEUED_TASKS = submit_normal_exports()
# Out:
# 2026-07-26 16:03:54,054 ERROR Export failed: ImageCollection.load: ImageCollection asset 'projects/sat-io/open-datasets/PML_V2' not found (does not exist or caller does not have access).
# 2026-07-26 16:03:54,071 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16:04:54,087 INFO Active cap reached; sleeping 60 seconds
# 2026-07-26 16
INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:22:08,440 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:23:08,463 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:24:08,480 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:25:08,492 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:26:08,521 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:27:08,528 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:28:08,534 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:29:08,544 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:30:08,551 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:31:08,560 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:32:08,576 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:33:08,590 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:34:08,610 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:35:08,622 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:36:08,629 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:37:08,641 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:38:08,660 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:39:08,668 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:40:08,680 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:41:08,687 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:42:08,697 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:43:08,716 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:44:08,734 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:45:08,744 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:46:08,764 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:47:08,798 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:48:08,818 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:49:08,825 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:50:08,839 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:51:08,849 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:52:08,863 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:53:08,876 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:54:08,894 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:55:08,906 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:56:08,931 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:57:08,943 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:58:08,962 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 07:59:08,971 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:00:08,984 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:01:08,996 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:02:09,018 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:03:09,036 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:04:09,054 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:05:09,069 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:06:09,096 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:07:09,103 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:08:09,114 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:09:09,126 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:10:09,136 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:11:09,151 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:12:09,165 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:13:09,182 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:14:09,209 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:15:09,228 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:16:09,262 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:17:09,283 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:18:09,299 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:19:09,306 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:20:09,322 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:21:09,337 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:22:09,353 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:23:09,363 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:24:09,393 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:25:09,415 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:26:09,434 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:27:09,481 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:28:09,490 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:29:09,500 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:30:09,510 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:31:09,525 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:32:09,546 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:33:09,559 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:34:09,575 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:35:09,589 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:36:09,608 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:37:09,619 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:38:09,634 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:39:09,646 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:40:09,655 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:41:09,661 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:42:09,674 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:43:09,689 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:44:09,701 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:45:09,714 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:46:09,730 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:47:09,740 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:48:09,755 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:49:09,768 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:50:09,780 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:51:09,787 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:52:09,811 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:53:09,822 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:54:09,835 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:55:09,843 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:56:09,851 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:57:09,859 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:58:09,870 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 08:59:09,886 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:00:09,902 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:01:09,918 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:02:09,944 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:03:09,960 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:04:09,969 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:05:09,983 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:06:09,994 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:07:10,008 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:08:10,017 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:09:10,026 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:10:10,035 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:11:10,047 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:12:10,059 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:13:10,074 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:14:10,093 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:15:10,105 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:16:10,125 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:17:10,136 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:18:10,143 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:19:10,161 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:20:10,170 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:21:10,191 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:22:10,204 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:23:10,209 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:24:10,217 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:25:10,233 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:26:10,240 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:27:10,249 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:28:10,259 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:29:10,269 INFO Active cap reached; sleeping 60 seconds
# 2026-07-27 09:32:34,287 INFO Active cap reached; sleeping 60 seconds

# %%
# %pip -q install compliance-checker
MAX_CONCURRENT = 20
MAX_DAILY_TASKS = 2500
# BatchManager enforces the local cap, retry backoff, registry writes, and non-blocking submission.

# %%
# GeoTIFFs remain in Google Drive as server-side export results.
# No local GeoTIFF-to-CF conversion is performed by this notebook.

# %%
OUTPUTS = list(DRY_RUN_OUTPUTS)
for output in OUTPUTS:
    write_manifest(DRIVE_ROOT, NOTEBOOK_ID, [output], DATASET['name'])

# %%
registry = pd.read_csv(registry_path(DRIVE_ROOT))
status = 'DRY_RUN_NO_EXPORT' if DRY_RUN else ('QUEUED' if QUEUED_TASKS else 'FAILED_OR_NOT_RUN')
print(pd.DataFrame([{'dataset': DATASET['name'], 'earth_engine_tasks': len(QUEUED_TASKS), 'status': status}]).to_string(index=False))
